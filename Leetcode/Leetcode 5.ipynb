# %%
def longestPalindrome(s: str) -> str:
    #forward = ''
    #backward = ''
    length = len(s)
    word = list(s)
    palindrome = ''
    #print(len(palindrome))
    #print(word)
    for i in range(0,length-1):
        if (length-1)-i < len(palindrome):
            break
        #print(i)
        forward = word[i]
        backward = word[i]
        for j in range(i+1, length):
            forward = forward + word[j]
            backward = word[j] + backward
            if forward == backward and len(forward) > len(palindrome):
                palindrome = forward
            #print(forward)
            #print(backward)
    return palindrome
    
    
longestPalindrome("ggigabhbahyfds")

# %%
def longestPalindrome(s: str) -> str:
    #forward = ''
    #backward = ''
    length = len(s)
    word = list(s)
    palindrome = ''
    print(len(palindrome))
    print(word)
    for i in range(0,length-1):
        if (length-1)-i < len(palindrome):
            break
        print(i)
        forward = word[i]
        backward = word[i]
        for j in range(length, i+1, -1):
            print(i)
            print(j)  
            if j-i<=len(palindrome):
                break
            else: 
                forward = ''.join(word[i:j])
                backward = forward[::-1]
                if forward == backward and len(forward) > len(palindrome):
                    palindrome = forward
                print(forward)
                print(backward)
            print(palindrome)
    return palindrome
    
    
longestPalindrome("ac")

# %%
def longestPalindrome(s: str) -> str:
    word = ""
    word_length = 0
    for i in range(len(s)):
        L, R = i, i
        while L>=0 and R<len(s) and s[L]==s[R]:
            if (R - L + 1) > word_length:
                word = s[L:R+1]
                word_length = (R - L + 1)
            L -= 1
            R += 1 
        
        L, R = i, i+1
        while L>=0 and R<len(s) and s[L]==s[R]:
            if (R - L + 1) > word_length:
                word = s[L:R+1]
                word_length = (R - L + 1)
            L -= 1
            R += 1 
            

    return word
    
    
longestPalindrome("ccc")

# %%
def find_word (s:str, L:int, R:int, word_length, word, i):
    while L>=0 and R<len(s) and s[L]==s[R]:
            if (R - L + 1) > word_length:
                word = s[L:R+1]
                word_length = (R - L + 1)
                print('when this ran',i)
                print(word)
            L -= 1
            R += 1 
    return word, word_length

def longestPalindrome(s: str) -> str:
    word = ""
    word_length = 0
    for i in range(len(s)):
        print(i)
        #if len(s) - i <= word_length:
        #    break
        print(i)
        #odd
        L, R = i, i
        word, word_length = find_word(s, L, R, word_length, word, i)
            
        #even
        L, R = i, i+1
        word, word_length = find_word(s, L, R, word_length, word, i)
            

    return word
    
    
longestPalindrome("hfhgfccc")

# %%
def find_word (s:str, L:int, R:int, word_length, word, i):
    while L>=0 and R<len(s) and s[L]==s[R]:
            if (R - L + 1) > word_length:
                word = s[L:R+1]
                word_length = (R - L + 1)
                print('when this ran',i)
                print(word)
            L -= 1
            R += 1 
    return word, word_length

def longestPalindrome(s: str) -> str:
    word = ""
    word_length = 0
    for i in range(len(s)):
        #odd
        L, R = i, i
        word, word_length = find_word(s, L, R, word_length, word, i)
        #even
        L, R = i, i+1
        word, word_length = find_word(s, L, R, word_length, word, i)
            

    return word
    
    
longestPalindrome("hfhgfccc")

# %%
def longestPalindrome(s: str) -> str:
    length = len(s)
    
    if length == 0:
        return 0
    
    start, max_len = 0,1
    
    for i in range(length):
        # this is the length a palindrome needs to be in order to become the new length
        df = i - max_len
        print('range i: {} with df = {}'.format(i,df))
        
        # odd
        # the s['range'] is the length of the prior palindrome + 1
        if df >=1 and s[df-1: i+1] == s[df-1: i+1][::-1]:
            start = df-1
            max_len +=2
            print(s[start: start + max_len])
            continue
        # even    
        if df>=0 and s[df: i+1] == s[df: i+1][::-1]:
            start = df
            max_len +=1
            print('Even: start {} with max_len {}'.format(df, max_len))
            print('Even: {}'.format(s[start: start + max_len]))
 
    return s[start: start + max_len]
    
    
#longestPalindrome("ggigabhbahyfds")    
#longestPalindrome("xyxabbbxbbbas")   
longestPalindrome("abcdefgfedcba")

# %%
xyxab bbxbb bas
