# %%
# Reading CSV files
import csv

with open('financial_Data.csv', mode='r') as file:
    # create a csv reader
    csv_reader = csv.reader(file)

    # iterate through the rows
    for row in csv_reader:
        print(row)
# Out:
# ['ï»¿Data', 'Finance']
# ['ABC Inc', '1000']
# ['ABC Inc', '1010']
# ['ABC Inc', '2000']
# ['ABC Inc', '2010']

# %%
# missing value logic - not runable code
data = pd.read_csv('sales_data.csv')

# fill missing values with the mean
data.fillna(data.mean(),inplace-True)

# %%
# IQR for outliers
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3-Q1

# Define upper and lower bounds
lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR

# Remove outliers
data = [(data >= lower_bound) & (data <= upper_bound)]

# %%
import matplotlib.pyplot as plt

# Data for line  - data not provided in book
quarters = 
years = 
revenue = 

# Plot line chart
for i, year in enumerate(year):
    plt.plot(quarters, revenue, label=year)

# Add labels
plt.xlabel('Quarters')
plt.ylabel('Revenue (in USD)')
plt.title('Quarterly Revenue Trends (2018-2022)')
plt.legend()
plt.show()

# %%
# pg50
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y, label='Sine Wave', color='blue',
        linestyle='--', marker='o', markersize=4,
        markerfacecolor='red', markeredgecolor='blue')
ax.set_xlabel('Time')
ax.set_ylabel('Amplitude')
ax.set_title('Customized Sine Wave')
# Out:
# Text(0.5, 1.0, 'Customized Sine Wave')

# %%
# see pg 54

# Sample data not provided
quarters = 
company_a_revenue = 
company_b_revenue = 

plt.plot(quarters, company_a_revenue, label='Company A',
         color='b', marker='o', linestyle='-', linewidth=2)
plt.plot(quarters, company_b_revenue, label='Company B',
         color='g', marker='s', linestyle='--', linewidth=2)

plt.xlabel('Quarter')
plt.ylabel('Revenue (in USD)')
plt.title('Company Revenue Comparison(2023)')
plt.legend()

plt.annotations('Record Break', xy=(quarters, company_a_revenue),
                xytext=(3.5, 310000), arrowprops=dict(facecolor='black',
                                                      shrink=0.05))

plt.show()
