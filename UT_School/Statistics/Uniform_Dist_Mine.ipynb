# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
book_count = pd.read_csv("bookseller.csv")
book_count.head()
# Out:
#    S.No        Date  Number of Books Sold
# 0     1  01-01-2020                    90
# 1     2  02-01-2020                   100
# 2     3  03-01-2020                   100
# 3     4  04-01-2020                    97
# 4     5  05-01-2020                    93

# %%
plt.hist(book_count['Number of Books Sold'], bins=11, rwidth=0.9, density=True)
plt.axhline(1/11, color='red')
plt.xlabel('Number of books sold')
plt.ylabel('Density')
plt.title('Data Distribution')
plt.show()

# %%
from scipy.stats import uniform
k = np.arange(90,101)
probs = uniform.pdf(k, loc=90, scale=11)
probs
# Out:
# array([0.09090909, 0.09090909, 0.09090909, 0.09090909, 0.09090909,
#        0.09090909, 0.09090909, 0.09090909, 0.09090909, 0.09090909,
#        0.09090909])

# %%
bar1 = plt.bar(x=k, height=probs)
for i in range (6,11):
    bar1[i].set_color('r')
    bar1[i].set_width(0.5)
    bar1[i].set_hatch('x')
plt.xlabel('Number of books sold')
plt.ylabel('Probability')
plt.title('Discrete Uniform Distribution X~U(90,100)')
plt.show()

# %%
print(bar1[0])
print(bar1[1])
print(bar1[2])
# Out:
# Rectangle(xy=(89.6, 0), width=0.8, height=0.0909091, angle=0)
# Rectangle(xy=(90.6, 0), width=0.8, height=0.0909091, angle=0)
# Rectangle(xy=(91.6, 0), width=0.8, height=0.0909091, angle=0)

# %%
type(bar1[0])
# Out:
# matplotlib.patches.Rectangle

# %%
uniform.sf(96, loc=90, scale=11)
# Out:
# 0.4545454545454546

# %%
bar1 = plt.bar(x=k, height=probs)
for i in range(0,3):
    bar1[i].set_color('r')
plt.xlabel('Number of books sold')
plt.ylabel('Probability')
plt.title('Discrete Uniform Distribution X~U(90,100)')
plt.show()

# %%
3/11
# Out:
# 0.2727272727272727

# %%
uniform.cdf(93, loc=90, scale=11)
# Out:
# 0.2727272727272727

# %%
debugging = pd.read_csv('debugging.csv')
debugging.head()
# Out:
#    Bug ID  Time Taken to fix the bug
# 0   12986                       2.42
# 1   12987                       2.03
# 2   12988                       2.74
# 3   12989                       3.21
# 4   12990                       3.40

# %%
uniform.sf(4.2, loc=1, scale=4)
# Out:
# 0.19999999999999996

# %%
plt.hist(debugging['Time Taken to fix the bug'], density=True)
plt.axhline(1/4, color='red')
plt.xlabel('Time required to fix bug')
plt.ylabel('Probability')
plt.title('Data Distribution')
plt.show()

# %%
sns.displot(debugging['Time Taken to fix the bug'], kde=True)
plt.show()

# %%
from scipy.stats import uniform
x = np.linspace(1,5, 50)
probs = uniform.pdf(x, loc=1, scale=4)

# %%
x1 = np.linspace(1,3,25)
plt.plot(x, probs)
plt.fill_between(x, probs)
plt.fill_between(x1, uniform.pdf(x=x1, loc=1, scale=4), color='r')
plt.xlabel("Time required for bug fixing")
plt.ylabel("Probability")
plt.title("Continuous Uniform Distribution: X ~ U(1,5)")
plt.show()

# %%
uniform.cdf(x=3, loc=1, scale=4)
# Out:
# 0.5

# %%
x1 = np.linspace(2,5,10)
plt.plot(x, probs)
plt.fill_between(x, probs)
plt.fill_between(x1, uniform.pdf(x=x1, loc=1, scale=4), color="r")
plt.xlabel("Time required for bug fixing")
plt.ylabel("Probability")
plt.title("Continuous Uniform Distribution: X ~ U(1,5)")
plt.show()

# %%
uniform.sf(2, loc=1, scale=4)
# Out:
# 0.75

# %%
uniform.ppf(0.5, loc=1, scale=4)
# Out:
# 3.0
