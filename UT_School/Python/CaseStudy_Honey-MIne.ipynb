# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
honeyprod = pd.read_csv('honeyproduction1998-2016.csv')
honeyprod.head()
# Out:
#         state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0     Alabama  16000.00           71  1136000.00   159000.00        0.72
# 1     Arizona  55000.00           60  3300000.00  1485000.00        0.64
# 2    Arkansas  53000.00           65  3445000.00  1688000.00        0.59
# 3  California 450000.00           83 37350000.00 12326000.00        0.62
# 4    Colorado  27000.00           72  1944000.00  1594000.00        0.70
#
#     prodvalue  year
# 0   818000.00  1998
# 1  2112000.00  1998
# 2  2033000.00  1998
# 3 23157000.00  1998
# 4  1361000.00  1998

# %%
honeyprod.shape
# Out:
# (785, 8)

# %%
honeyprod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785 entries, 0 to 784
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        785 non-null    object
#  1   numcol       785 non-null    float64
#  2   yieldpercol  785 non-null    int64
#  3   totalprod    785 non-null    float64
#  4   stocks       785 non-null    float64
#  5   priceperlb   785 non-null    float64
#  6   prodvalue    785 non-null    float64
#  7   year         785 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 49.2+ KB

# %%
honeyprod.describe(include = 'all')
# Out:
#           state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# count       785    785.00       785.00      785.00      785.00      785.00
# unique       44       NaN          NaN         NaN         NaN         NaN
# top     Alabama       NaN          NaN         NaN         NaN         NaN
# freq         19       NaN          NaN         NaN         NaN         NaN
# mean        NaN  61686.62        60.58  4140956.69  1257629.30        1.70
# std         NaN  92748.94        19.43  6884593.86  2211793.82        0.93
# min         NaN   2000.00        19.00    84000.00     8000.00        0.49
# 25%         NaN   9000.00        46.00   470000.00   119000.00        1.05
# 50%         NaN  26000.00        58.00  1500000.00   391000.00        1.48
# 75%         NaN  65000.00        72.00  4096000.00  1380000.00        2.04
# max         NaN 510000.00       136.00 46410000.00 13800000.00        7.09
#
#          prodvalue    year
# count       785.00  785.00
# unique         NaN     NaN
# top            NaN     NaN
# freq           NaN     NaN
# mean    5489738.85 2006.82
# std     9425393.88    5.49
# min      162000.00 1998.00
# 25%      901000.00 2002.00
# 50%     2112000.00 2007.00
# 75%     5559000.00 2012.00
# max    83859000.00 2016.00

# %%
honeyprod.describe()
# Out:
#          numcol  yieldpercol   totalprod      stocks  priceperlb   prodvalue  \
# count    785.00       785.00      785.00      785.00      785.00      785.00
# mean   61686.62        60.58  4140956.69  1257629.30        1.70  5489738.85
# std    92748.94        19.43  6884593.86  2211793.82        0.93  9425393.88
# min     2000.00        19.00    84000.00     8000.00        0.49   162000.00
# 25%     9000.00        46.00   470000.00   119000.00        1.05   901000.00
# 50%    26000.00        58.00  1500000.00   391000.00        1.48  2112000.00
# 75%    65000.00        72.00  4096000.00  1380000.00        2.04  5559000.00
# max   510000.00       136.00 46410000.00 13800000.00        7.09 83859000.00
#
#          year
# count  785.00
# mean  2006.82
# std      5.49
# min   1998.00
# 25%   2002.00
# 50%   2007.00
# 75%   2012.00
# max   2016.00

# %%
plt.figure(figsize=(15,7))
sns.histplot(data=honeyprod, x='numcol', kde=True)
# Out:
# <Axes: xlabel='numcol', ylabel='Count'>

# %%
sns.boxplot(data=honeyprod, x='numcol')
# Out:
# <Axes: xlabel='numcol'>

# %%
plt.figure(figsize=(15,7))
sns.histplot(data=honeyprod, x='yieldpercol', kde=True)
# Out:
# <Axes: xlabel='yieldpercol', ylabel='Count'>

# %%
sns.boxplot(data=honeyprod, x='yieldpercol')
# Out:
# <Axes: xlabel='yieldpercol'>

# %%
plt.figure(figsize=(15,7))
sns.histplot(data=honeyprod, x='totalprod', kde=True)
# Out:
# <Axes: xlabel='totalprod', ylabel='Count'>

# %%
sns.boxplot(data=honeyprod, x='totalprod')
# Out:
# <Axes: xlabel='totalprod'>

# %%
plt.figure(figsize=(15,7))
sns.histplot(data=honeyprod, x='priceperlb', kde=True)
# Out:
# <Axes: xlabel='priceperlb', ylabel='Count'>

# %%
sns.boxplot(data=honeyprod, x='priceperlb')
# Out:
# <Axes: xlabel='priceperlb'>

# %%
plt.figure(figsize=(15,7))
sns.histplot(data=honeyprod, x='prodvalue', kde=True)
# Out:
# <Axes: xlabel='prodvalue', ylabel='Count'>

# %%
sns.boxplot(data=honeyprod, x='prodvalue')
# Out:
# <Axes: xlabel='prodvalue'>

# %%
plt.figure(figsize=(15,7))
sns.histplot(data=honeyprod, x='stocks', kde=True)
# Out:
# <Axes: xlabel='stocks', ylabel='Count'>

# %%
sns.boxplot(data=honeyprod, x='stocks')
# Out:
# <Axes: xlabel='stocks'>

# %%
plt.figure(figsize=(15,7))
sns.pairplot(honeyprod, diag_kind='kde')

# %%
honey_prod_without_state = honeyprod.drop(columns=['state','year'])

# %%
honey_prod_without_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785 entries, 0 to 784
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   numcol       785 non-null    float64
#  1   yieldpercol  785 non-null    int64
#  2   totalprod    785 non-null    float64
#  3   stocks       785 non-null    float64
#  4   priceperlb   785 non-null    float64
#  5   prodvalue    785 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 36.9 KB

# %%
correlation = honey_prod_without_state.corr()
correlation
# Out:
#              numcol  yieldpercol  totalprod  stocks  priceperlb  prodvalue
# numcol         1.00         0.22       0.95    0.82       -0.21       0.90
# yieldpercol    0.22         1.00       0.38    0.36       -0.36       0.26
# totalprod      0.95         0.38       1.00    0.88       -0.24       0.90
# stocks         0.82         0.36       0.88    1.00       -0.28       0.71
# priceperlb    -0.21        -0.36      -0.24   -0.28        1.00      -0.06
# prodvalue      0.90         0.26       0.90    0.71       -0.06       1.00

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data=correlation, annot=True, cmap='Spectral')
# Out:
# <Axes: >
