# %% [markdown]
# #### Selenium - Handling Cookies with Javascript

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
chrome_options = Options()
chrome_options.add_argument('--headless')
CHROMEDRIVER_PATH = "C:/Users/timry/.wdm/drivers/chromedriver/win64/139.0.7258.138/chromedriver-win32/chromedriver.exe"
driver = webdriver.Chrome(
    service = Service(CHROMEDRIVER_PATH),
    options = chrome_options)

driver.get('http://pythonscraping.com')
driver.implicitly_wait(1)
print(driver.get_cookies())
# Out:
# [{'domain': '.pythonscraping.com', 'expiry': 1790634254, 'httpOnly': False, 'name': '_ga', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': 'GA1.1.29174000.1756074254'}, {'domain': '.pythonscraping.com', 'expiry': 1790634254, 'httpOnly': False, 'name': '_ga_G60J5CGY1N', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': 'GS2.1.s1756074254$o1$g0$t1756074254$j60$l0$h0'}]

# %% [markdown]
# #### Selenium - Avoiding Honeypots

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.common.by import By

chrome_options = Options()
chrome_options.add_argument('--headless')
CHROMEDRIVER_PATH = "C:/Users/timry/.wdm/drivers/chromedriver/win64/139.0.7258.138/chromedriver-win32/chromedriver.exe"
driver = webdriver.Chrome(
    service = Service(CHROMEDRIVER_PATH),
    options = chrome_options)

driver.get('http://pythonscraping.com/pages/itsatrap.html')
links = driver.find_elements(By.TAG_NAME, 'a')
for link in links:
    if not link.is_displayed():
        print(f'The link {link.get_attribute("href")} is a trap')

fields = driver.find_elements(By.TAG_NAME, 'input')
for field in fields:
    if not field.is_displayed():
        print(f'Do not change value of {field.get_attribute("name")}')
# Out:
# The link http://pythonscraping.com/dontgohere is a trap
# Do not change value of phone
# Do not change value of email
